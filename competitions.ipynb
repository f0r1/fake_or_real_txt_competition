# %%
# -*- coding: utf-8 -*-
# Pipeline: The Messenger (Real vs Fake) — CatBoostClassifier
# Требования: python>=3.9, pandas, numpy, scikit-learn, catboost

import os, re, pathlib, warnings
from glob import glob
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, StratifiedKFold, RandomizedSearchCV
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, accuracy_score
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS
from catboost import CatBoostClassifier

warnings.filterwarnings("ignore")

# %%
# ----------------------------
# Константы
# ----------------------------
DATA_DIR = "data"                          # корневая папка с train/, test/, train.csv
TRAIN_DIR = os.path.join(DATA_DIR, "train")
TEST_DIR  = os.path.join(DATA_DIR, "test")
TRAIN_CSV = os.path.join(DATA_DIR, "train.csv")
RANDOM_STATE = 42

# %%
# ----------------------------
# Утилиты
# ----------------------------
_digit_re   = re.compile(r"\d")
_punct_re   = re.compile(r"[^\w\s]")
_upper_re   = re.compile(r"[A-Z]")
_sent_split = re.compile(r"[.!?]+")

STOPWORDS = set(ENGLISH_STOP_WORDS)

# %%
def read_text(path: str) -> str:
    # безопасное чтение с нормализацией пробелов
    try:
        txt = pathlib.Path(path).read_text(encoding="utf-8", errors="ignore")
    except Exception:
        txt = pathlib.Path(path).read_text(encoding="latin-1", errors="ignore")
    return " ".join(txt.split())

def extract_id_from_article_path(article_path: str) -> int:
    # ожидаем article_0000 -> 0
    m = re.search(r"article_(\d+)", article_path)
    if not m:
        raise ValueError(f"Не удалось извлечь id из {article_path}")
    return int(m.group(1))

def text_stats(text: str, prefix: str) -> dict:
    # Отдельные фичи на ТЕКСТ (без разностей)
    if not text:
        return {
            f"{prefix}_len_chars": 0,
            f"{prefix}_len_words": 0,
            f"{prefix}_mean_word_len": 0.0,
            f"{prefix}_uniq_words": 0,
            f"{prefix}_ttr": 0.0,
            f"{prefix}_digit_ratio": 0.0,
            f"{prefix}_punct_ratio": 0.0,
            f"{prefix}_upper_ratio": 0.0,
            f"{prefix}_stopword_ratio": 0.0,
            f"{prefix}_sentences": 0,
        }

    words = text.split()
    n_chars = len(text)
    n_words = len(words)
    uniq = len(set(w.lower() for w in words))
    avg_wlen = np.mean([len(w) for w in words]) if n_words else 0.0
    digits = len(_digit_re.findall(text))
    puncts = len(_punct_re.findall(text))
    uppers = len(_upper_re.findall(text))
    sents  = len([s for s in _sent_split.split(text) if s.strip()])

    stop_cnt = sum(1 for w in (w.lower() for w in words) if w in STOPWORDS)

    return {
        f"{prefix}_len_chars": n_chars,
        f"{prefix}_len_words": n_words,
        f"{prefix}_mean_word_len": float(avg_wlen),
        f"{prefix}_uniq_words": uniq,
        f"{prefix}_ttr": float(uniq / n_words) if n_words else 0.0,  # type-token ratio
        f"{prefix}_digit_ratio": float(digits / n_chars) if n_chars else 0.0,
        f"{prefix}_punct_ratio": float(puncts / n_chars) if n_chars else 0.0,
        f"{prefix}_upper_ratio": float(uppers / n_chars) if n_chars else 0.0,
        f"{prefix}_stopword_ratio": float(stop_cnt / n_words) if n_words else 0.0,
        f"{prefix}_sentences": sents,
    }

def build_split_df(root_dir: str) -> pd.DataFrame:
    """
    Читает пары статей: .../article_xxxx/file_1.txt, file_2.txt
    Возвращает DataFrame: id, text1, text2 + числовые фичи t1_*, t2_*
    """
    rows = []
    articles = sorted(glob(os.path.join(root_dir, "article_*")))
    if not articles:
        raise FileNotFoundError(f"Не найдены папки article_* в {root_dir}")

    for art_dir in articles:
        id_ = extract_id_from_article_path(art_dir)
        f1 = os.path.join(art_dir, "file_1.txt")
        f2 = os.path.join(art_dir, "file_2.txt")
        if not os.path.exists(f1) or not os.path.exists(f2):
            raise FileNotFoundError(f"Отсутствуют file_1.txt/file_2.txt в {art_dir}")

        t1 = read_text(f1)
        t2 = read_text(f2)

        feats = {}
        feats.update(text_stats(t1, "t1"))
        feats.update(text_stats(t2, "t2"))

        rows.append({
            "id": id_,
            "text1": t1,
            "text2": t2,
            **feats
        })
    df = pd.DataFrame(rows).sort_values("id").reset_index(drop=True)
    return df

# %%
# ----------------------------
# Загрузка данных
# ----------------------------
train_df_pairs = build_split_df(TRAIN_DIR)                   # id, text1, text2, t1_*, t2_*
train_gt = pd.read_csv(TRAIN_CSV)                            # id, real_text_id ∈ {1,2}

# %%
# Проверим соответствие id
merged = train_df_pairs.merge(train_gt, on="id", how="inner")
assert len(merged) == len(train_df_pairs), "Несовпадение id между парами и train.csv"

# %%
# Целевая переменная: 1 => file_1 реал, 0 => file_2 реал
merged["target"] = (merged["real_text_id"] == 1).astype(int)

# %%
# Финальные признаки: две текстовые + набор числовых по каждому тексту
text_cols = ["text1", "text2"]
num_cols = [c for c in merged.columns if c.startswith("t1_") or c.startswith("t2_")]
feature_cols = text_cols + num_cols

X = merged[feature_cols].copy()
y = merged["target"].astype(int).copy()

# %%
# ----------------------------
# Валидация
# ----------------------------
X_train, X_val, y_train, y_val = train_test_split(
    X, y,
    test_size=0.2,
    stratify=y,
    random_state=RANDOM_STATE
)

# %%
# ----------------------------
# Модель и поиск гиперпараметров (6-fold CV)
# ----------------------------
cv = StratifiedKFold(n_splits=6, shuffle=True, random_state=RANDOM_STATE)

base_model = CatBoostClassifier(
    loss_function="Logloss",
    eval_metric="AUC",
    random_seed=RANDOM_STATE,
    verbose=100,
    text_features=text_cols,
    use_best_model=True,
    early_stopping_rounds=50
    # включим текстовую обработку по умолчанию
)

param_dist = {
    "depth":            [4, 6, 8, 10],
    "learning_rate":    [0.03, 0.05, 0.1],
    "l2_leaf_reg":      [1, 3, 5, 7, 10],
    "iterations":       [500, 1000, 2000],
    "bagging_temperature": [0.0, 0.25, 0.5, 1.0],
    "random_strength":  [0.0, 0.5, 1.0, 2.0],
    "border_count":     [32, 64, 128],
    # Можно добавить текстовые настройки при необходимости:
    # "text_processing": [...]
}

search = RandomizedSearchCV(
    estimator=base_model,
    param_distributions=param_dist,
    n_iter=20,                 # при необходимости увеличить/уменьшить
    scoring="roc_auc",
    cv=cv,
    refit=True,
    n_jobs=-1,
    verbose=100,
    random_state=RANDOM_STATE
)

# %%
# ВАЖНО: передаем, какие признаки — текстовые
search.fit(
    X_train, y_train,
    text_features=text_cols,
    verbose=100,
    eval_set=(X_val, y_val)
)

best_model = search.best_estimator_
print("=== Лучшие параметры ===")
print(search.best_params_)
print("=== Лучший CV AUC ===")
print(search.best_score_)
# Out:
# Fitting 6 folds for each of 20 candidates, totalling 120 fits
# [CV 2/6; 1/20] START bagging_temperature=1.0, border_count=64, depth=4, iterations=1000, l2_leaf_reg=1, learning_rate=0.1, random_strength=1.0
# [CV 1/6; 2/20] START bagging_temperature=0.0, border_count=64, depth=4, iterations=2000, l2_leaf_reg=3, learning_rate=0.1, random_strength=0.0
# [CV 1/6; 1/20] START bagging_temperature=1.0, border_count=64, depth=4, iterations=1000, l2_leaf_reg=1, learning_rate=0.1, random_strength=1.0
# [CV 2/6; 2/20] START bagging_temperature=0.0, border_count=64, depth=4, iterations=2000, l2_leaf_reg=3, learning_rate=0.1, random_strength=0.0
# [CV 6/6; 1/20] START bagging_temperature=1.0, border_count=64, depth=4, iterations=1000, l2_leaf_reg=1, learning_rate=0.1, random_strength=1.0
# [CV 5/6; 1/20] START bagging_temperature=1.0, border_count=64, depth=4, iterations=1000, l2_leaf_reg=1, learning_rate=0.1, random_strength=1.0
# [CV 4/6; 1/20] START bagging_temperature=1.0, border_count=64, depth=4, iterations=1000, l2_leaf_reg=1, learning_rate=0.1, random_strength=1.0
# [CV 3/6; 1/20] START bagging_temperature=1.0, border_count=64, depth=4, iterations=1000, l2_leaf_reg=1, learning_rate=0.1, random_strength=1.0
# 0:	test: 0.6222222	best: 0.6222222 (0)	total: 75.5ms	remaining: 1m 15s
# 0:	test: 0.8333333	best: 0.8333333 (0)	total: 92.8ms	remaining: 3m 5s
# 0:	test: 0.6166667	best: 0.6166667 (0)	total: 128ms	remaining: 2m 7s
# 0:	test: 0.7333333	best: 0.7333333 (0)	total: 154ms	remaining: 5m 8s
# 0:	test: 0.6000000	best: 0.6000000 (0)	total: 155ms	remaining: 2m 35s
# 0:	test: 0.6444444	best: 0.6444444 (0)	total: 153ms	remaining: 2m 33s
# 0:	test: 0.6777778	best: 0.6777778 (0)	total: 194ms	remaining: 3m 14s
# 0:	test: 0.6000000	best: 0.6000000 (0)	total: 192ms	remaining: 3m 11s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.7611111111
# bestIteration = 1
#
# Shrink model to first 2 iterations.
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.8333333333
# bestIteration = 0
#
# Shrink model to first 1 iterations.
# [CV 2/6; 2/20] END bagging_temperature=0.0, border_count=64, depth=4, iterations=2000, l2_leaf_reg=3, learning_rate=0.1, random_strength=0.0;, score=0.821 total time=   5.5s
# [CV 1/6; 2/20] END bagging_temperature=0.0, border_count=64, depth=4, iterations=2000, l2_leaf_reg=3, learning_rate=0.1, random_strength=0.0;, score=0.857 total time=   5.6s
# [CV 3/6; 2/20] START bagging_temperature=0.0, border_count=64, depth=4, iterations=2000, l2_leaf_reg=3, learning_rate=0.1, random_strength=0.0
# [CV 4/6; 2/20] START bagging_temperature=0.0, border_count=64, depth=4, iterations=2000, l2_leaf_reg=3, learning_rate=0.1, random_strength=0.0
# 0:	test: 0.7166667	best: 0.7166667 (0)	total: 103ms	remaining: 3m 25s
# 0:	test: 0.5888889	best: 0.5888889 (0)	total: 87.6ms	remaining: 2m 55s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.8388888889
# bestIteration = 10
#
# Shrink model to first 11 iterations.
# [CV 1/6; 1/20] END bagging_temperature=1.0, border_count=64, depth=4, iterations=1000, l2_leaf_reg=1, learning_rate=0.1, random_strength=1.0;, score=1.000 total time=   6.6s
# [CV 5/6; 2/20] START bagging_temperature=0.0, border_count=64, depth=4, iterations=2000, l2_leaf_reg=3, learning_rate=0.1, random_strength=0.0
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.8777777778
# bestIteration = 13
#
# Shrink model to first 14 iterations.
# [CV 3/6; 1/20] END bagging_temperature=1.0, border_count=64, depth=4, iterations=1000, l2_leaf_reg=1, learning_rate=0.1, random_strength=1.0;, score=1.000 total time=   7.0s
# 0:	test: 0.7000000	best: 0.7000000 (0)	total: 116ms	remaining: 3m 52s
# [CV 6/6; 2/20] START bagging_temperature=0.0, border_count=64, depth=4, iterations=2000, l2_leaf_reg=3, learning_rate=0.1, random_strength=0.0
# 0:	test: 0.7277778	best: 0.7277778 (0)	total: 100ms	remaining: 3m 20s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.8555555556
# bestIteration = 19
#
# Shrink model to first 20 iterations.
# [CV 6/6; 1/20] END bagging_temperature=1.0, border_count=64, depth=4, iterations=1000, l2_leaf_reg=1, learning_rate=0.1, random_strength=1.0;, score=0.778 total time=   7.8s
# [CV 1/6; 3/20] START bagging_temperature=0.5, border_count=64, depth=6, iterations=2000, l2_leaf_reg=10, learning_rate=0.03, random_strength=1.0
# 0:	test: 0.7777778	best: 0.7777778 (0)	total: 221ms	remaining: 7m 20s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.9222222222
# bestIteration = 23
#
# Shrink model to first 24 iterations.
# [CV 5/6; 1/20] END bagging_temperature=1.0, border_count=64, depth=4, iterations=1000, l2_leaf_reg=1, learning_rate=0.1, random_strength=1.0;, score=0.944 total time=   8.3s
# [CV 2/6; 3/20] START bagging_temperature=0.5, border_count=64, depth=6, iterations=2000, l2_leaf_reg=10, learning_rate=0.03, random_strength=1.0
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.8222222222
# bestIteration = 28
#
# Shrink model to first 29 iterations.
# [CV 4/6; 1/20] END bagging_temperature=1.0, border_count=64, depth=4, iterations=1000, l2_leaf_reg=1, learning_rate=0.1, random_strength=1.0;, score=0.762 total time=   8.6s
# [CV 3/6; 3/20] START bagging_temperature=0.5, border_count=64, depth=6, iterations=2000, l2_leaf_reg=10, learning_rate=0.03, random_strength=1.0
# 0:	test: 0.6000000	best: 0.6000000 (0)	total: 144ms	remaining: 4m 47s
# 0:	test: 0.7500000	best: 0.7500000 (0)	total: 333ms	remaining: 11m 4s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.7888888889
# bestIteration = 42
#
# Shrink model to first 43 iterations.
# [CV 2/6; 1/20] END bagging_temperature=1.0, border_count=64, depth=4, iterations=1000, l2_leaf_reg=1, learning_rate=0.1, random_strength=1.0;, score=0.857 total time=  10.2s
# [CV 4/6; 3/20] START bagging_temperature=0.5, border_count=64, depth=6, iterations=2000, l2_leaf_reg=10, learning_rate=0.03, random_strength=1.0
# 0:	test: 0.6444444	best: 0.6444444 (0)	total: 274ms	remaining: 9m 8s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.8222222222
# bestIteration = 1
#
# Shrink model to first 2 iterations.
# [CV 3/6; 2/20] END bagging_temperature=0.0, border_count=64, depth=4, iterations=2000, l2_leaf_reg=3, learning_rate=0.1, random_strength=0.0;, score=0.881 total time=   6.5s
# [CV 5/6; 3/20] START bagging_temperature=0.5, border_count=64, depth=6, iterations=2000, l2_leaf_reg=10, learning_rate=0.03, random_strength=1.0
# 0:	test: 0.6444444	best: 0.6444444 (0)	total: 429ms	remaining: 14m 16s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.7333333333
# bestIteration = 15
#
# Shrink model to first 16 iterations.
# [CV 4/6; 2/20] END bagging_temperature=0.0, border_count=64, depth=4, iterations=2000, l2_leaf_reg=3, learning_rate=0.1, random_strength=0.0;, score=0.595 total time=   8.1s
# [CV 6/6; 3/20] START bagging_temperature=0.5, border_count=64, depth=6, iterations=2000, l2_leaf_reg=10, learning_rate=0.03, random_strength=1.0
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.7666666667
# bestIteration = 3
#
# Shrink model to first 4 iterations.
# [CV 5/6; 2/20] END bagging_temperature=0.0, border_count=64, depth=4, iterations=2000, l2_leaf_reg=3, learning_rate=0.1, random_strength=0.0;, score=1.000 total time=   7.1s
# [CV 1/6; 4/20] START bagging_temperature=0.5, border_count=64, depth=4, iterations=2000, l2_leaf_reg=5, learning_rate=0.05, random_strength=2.0
# 0:	test: 0.6000000	best: 0.6000000 (0)	total: 204ms	remaining: 6m 48s
# 0:	test: 0.6555556	best: 0.6555556 (0)	total: 357ms	remaining: 11m 54s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.8444444444
# bestIteration = 33
#
# Shrink model to first 34 iterations.
# [CV 6/6; 2/20] END bagging_temperature=0.0, border_count=64, depth=4, iterations=2000, l2_leaf_reg=3, learning_rate=0.1, random_strength=0.0;, score=0.917 total time=  12.1s
# [CV 2/6; 4/20] START bagging_temperature=0.5, border_count=64, depth=4, iterations=2000, l2_leaf_reg=5, learning_rate=0.05, random_strength=2.0
# 0:	test: 0.5166667	best: 0.5166667 (0)	total: 120ms	remaining: 3m 59s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.9388888889
# bestIteration = 9
#
# Shrink model to first 10 iterations.
# [CV 1/6; 4/20] END bagging_temperature=0.5, border_count=64, depth=4, iterations=2000, l2_leaf_reg=5, learning_rate=0.05, random_strength=2.0;, score=0.833 total time=   8.7s
# [CV 3/6; 4/20] START bagging_temperature=0.5, border_count=64, depth=4, iterations=2000, l2_leaf_reg=5, learning_rate=0.05, random_strength=2.0
# 0:	test: 0.6000000	best: 0.6000000 (0)	total: 119ms	remaining: 3m 57s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.8333333333
# bestIteration = 3
#
# Shrink model to first 4 iterations.
# [CV 2/6; 3/20] END bagging_temperature=0.5, border_count=64, depth=6, iterations=2000, l2_leaf_reg=10, learning_rate=0.03, random_strength=1.0;, score=0.833 total time=  17.2s
# [CV 4/6; 4/20] START bagging_temperature=0.5, border_count=64, depth=4, iterations=2000, l2_leaf_reg=5, learning_rate=0.05, random_strength=2.0
# 0:	test: 0.6555556	best: 0.6555556 (0)	total: 230ms	remaining: 7m 38s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.7666666667
# bestIteration = 1
#
# Shrink model to first 2 iterations.
# [CV 4/6; 3/20] END bagging_temperature=0.5, border_count=64, depth=6, iterations=2000, l2_leaf_reg=10, learning_rate=0.03, random_strength=1.0;, score=0.738 total time=  16.1s
# [CV 5/6; 4/20] START bagging_temperature=0.5, border_count=64, depth=4, iterations=2000, l2_leaf_reg=5, learning_rate=0.05, random_strength=2.0
# 0:	test: 0.6000000	best: 0.6000000 (0)	total: 201ms	remaining: 6m 41s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.9888888889
# bestIteration = 39
#
# Shrink model to first 40 iterations.
# [CV 2/6; 4/20] END bagging_temperature=0.5, border_count=64, depth=4, iterations=2000, l2_leaf_reg=5, learning_rate=0.05, random_strength=2.0;, score=0.905 total time=  12.7s
# [CV 6/6; 4/20] START bagging_temperature=0.5, border_count=64, depth=4, iterations=2000, l2_leaf_reg=5, learning_rate=0.05, random_strength=2.0
# 0:	test: 0.5833333	best: 0.5833333 (0)	total: 156ms	remaining: 5m 11s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.8111111111
# bestIteration = 27
#
# Shrink model to first 28 iterations.
# [CV 1/6; 3/20] END bagging_temperature=0.5, border_count=64, depth=6, iterations=2000, l2_leaf_reg=10, learning_rate=0.03, random_strength=1.0;, score=0.952 total time=  25.2s
# [CV 1/6; 5/20] START bagging_temperature=0.5, border_count=64, depth=10, iterations=2000, l2_leaf_reg=5, learning_rate=0.1, random_strength=1.0
# 0:	test: 0.7777778	best: 0.7777778 (0)	total: 296ms	remaining: 9m 51s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.9111111111
# bestIteration = 12
#
# Shrink model to first 13 iterations.
# [CV 4/6; 4/20] END bagging_temperature=0.5, border_count=64, depth=4, iterations=2000, l2_leaf_reg=5, learning_rate=0.05, random_strength=2.0;, score=0.714 total time=   8.6s
# [CV 2/6; 5/20] START bagging_temperature=0.5, border_count=64, depth=10, iterations=2000, l2_leaf_reg=5, learning_rate=0.1, random_strength=1.0
# 0:	test: 0.6777778	best: 0.6777778 (0)	total: 552ms	remaining: 18m 23s
# 100:	test: 0.8777778	best: 0.9555556 (78)	total: 13.5s	remaining: 4m 13s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.9555555556
# bestIteration = 19
#
# Shrink model to first 20 iterations.
# [CV 6/6; 3/20] END bagging_temperature=0.5, border_count=64, depth=6, iterations=2000, l2_leaf_reg=10, learning_rate=0.03, random_strength=1.0;, score=1.000 total time=  24.6s
# [CV 3/6; 5/20] START bagging_temperature=0.5, border_count=64, depth=10, iterations=2000, l2_leaf_reg=5, learning_rate=0.1, random_strength=1.0
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.9222222222
# bestIteration = 25
#
# Shrink model to first 26 iterations.
# [CV 5/6; 3/20] END bagging_temperature=0.5, border_count=64, depth=6, iterations=2000, l2_leaf_reg=10, learning_rate=0.03, random_strength=1.0;, score=1.000 total time=  26.3s
# [CV 4/6; 5/20] START bagging_temperature=0.5, border_count=64, depth=10, iterations=2000, l2_leaf_reg=5, learning_rate=0.1, random_strength=1.0
# 0:	test: 0.6000000	best: 0.6000000 (0)	total: 97.7ms	remaining: 3m 15s
# 0:	test: 0.6444444	best: 0.6444444 (0)	total: 738ms	remaining: 24m 34s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.9555555556
# bestIteration = 78
#
# Shrink model to first 79 iterations.
# [CV 3/6; 4/20] END bagging_temperature=0.5, border_count=64, depth=4, iterations=2000, l2_leaf_reg=5, learning_rate=0.05, random_strength=2.0;, score=0.881 total time=  18.0s
# [CV 5/6; 5/20] START bagging_temperature=0.5, border_count=64, depth=10, iterations=2000, l2_leaf_reg=5, learning_rate=0.1, random_strength=1.0
# 100:	test: 0.8444444	best: 0.8444444 (98)	total: 14.8s	remaining: 4m 37s
# 100:	test: 0.8333333	best: 0.9111111 (60)	total: 32.4s	remaining: 10m 8s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.7888888889
# bestIteration = 33
#
# Shrink model to first 34 iterations.
# [CV 6/6; 4/20] END bagging_temperature=0.5, border_count=64, depth=4, iterations=2000, l2_leaf_reg=5, learning_rate=0.05, random_strength=2.0;, score=0.889 total time=  12.9s
# [CV 6/6; 5/20] START bagging_temperature=0.5, border_count=64, depth=10, iterations=2000, l2_leaf_reg=5, learning_rate=0.1, random_strength=1.0
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.9111111111
# bestIteration = 60
#
# Shrink model to first 61 iterations.
# 0:	test: 0.7500000	best: 0.7500000 (0)	total: 309ms	remaining: 10m 17s
# [CV 3/6; 3/20] END bagging_temperature=0.5, border_count=64, depth=6, iterations=2000, l2_leaf_reg=10, learning_rate=0.03, random_strength=1.0;, score=0.976 total time=  36.7s
# [CV 1/6; 6/20] START bagging_temperature=0.5, border_count=128, depth=8, iterations=2000, l2_leaf_reg=5, learning_rate=0.03, random_strength=0.5
# 0:	test: 0.7666667	best: 0.7666667 (0)	total: 5.59s	remaining: 3h 6m 15s
# 0:	test: 0.7388889	best: 0.7388889 (0)	total: 1.61s	remaining: 53m 34s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.8666666667
# bestIteration = 101
#
# Shrink model to first 102 iterations.
# [CV 5/6; 4/20] END bagging_temperature=0.5, border_count=64, depth=4, iterations=2000, l2_leaf_reg=5, learning_rate=0.05, random_strength=2.0;, score=0.972 total time=  23.9s
# [CV 2/6; 6/20] START bagging_temperature=0.5, border_count=128, depth=8, iterations=2000, l2_leaf_reg=5, learning_rate=0.03, random_strength=0.5
# 0:	test: 0.8000000	best: 0.8000000 (0)	total: 1.48s	remaining: 49m 9s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.7388888889
# bestIteration = 0
#
# Shrink model to first 1 iterations.
# [CV 1/6; 6/20] END bagging_temperature=0.5, border_count=128, depth=8, iterations=2000, l2_leaf_reg=5, learning_rate=0.03, random_strength=0.5;, score=0.714 total time= 1.3min
# [CV 3/6; 6/20] START bagging_temperature=0.5, border_count=128, depth=8, iterations=2000, l2_leaf_reg=5, learning_rate=0.03, random_strength=0.5
# 0:	test: 0.8055556	best: 0.8055556 (0)	total: 1.85s	remaining: 1h 1m 31s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.8333333333
# bestIteration = 9
#
# Shrink model to first 10 iterations.
# [CV 2/6; 6/20] END bagging_temperature=0.5, border_count=128, depth=8, iterations=2000, l2_leaf_reg=5, learning_rate=0.03, random_strength=0.5;, score=0.952 total time= 1.4min
# [CV 4/6; 6/20] START bagging_temperature=0.5, border_count=128, depth=8, iterations=2000, l2_leaf_reg=5, learning_rate=0.03, random_strength=0.5
# 0:	test: 0.5833333	best: 0.5833333 (0)	total: 1.79s	remaining: 59m 44s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.8444444444
# bestIteration = 10
#
# Shrink model to first 11 iterations.
# [CV 3/6; 6/20] END bagging_temperature=0.5, border_count=128, depth=8, iterations=2000, l2_leaf_reg=5, learning_rate=0.03, random_strength=0.5;, score=0.952 total time= 1.5min
# [CV 5/6; 6/20] START bagging_temperature=0.5, border_count=128, depth=8, iterations=2000, l2_leaf_reg=5, learning_rate=0.03, random_strength=0.5
# 0:	test: 0.7000000	best: 0.7000000 (0)	total: 2.1s	remaining: 1h 10m 8s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.7944444444
# bestIteration = 2
#
# Shrink model to first 3 iterations.
# [CV 4/6; 5/20] END bagging_temperature=0.5, border_count=64, depth=10, iterations=2000, l2_leaf_reg=5, learning_rate=0.1, random_strength=1.0;, score=0.726 total time= 3.2min
# [CV 6/6; 6/20] START bagging_temperature=0.5, border_count=128, depth=8, iterations=2000, l2_leaf_reg=5, learning_rate=0.03, random_strength=0.5
# 0:	test: 0.6277778	best: 0.6277778 (0)	total: 534ms	remaining: 17m 48s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.8722222222
# bestIteration = 4
#
# Shrink model to first 5 iterations.
# [CV 1/6; 5/20] END bagging_temperature=0.5, border_count=64, depth=10, iterations=2000, l2_leaf_reg=5, learning_rate=0.1, random_strength=1.0;, score=0.952 total time= 3.7min
# [CV 1/6; 7/20] START bagging_temperature=0.0, border_count=32, depth=8, iterations=1000, l2_leaf_reg=7, learning_rate=0.1, random_strength=1.0
# 0:	test: 0.7777778	best: 0.7777778 (0)	total: 209ms	remaining: 3m 28s
# 100:	test: 0.7222222	best: 0.7444444 (59)	total: 2m 50s	remaining: 53m 23s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.9222222222
# bestIteration = 1
#
# Shrink model to first 2 iterations.
# [CV 5/6; 6/20] END bagging_temperature=0.5, border_count=128, depth=8, iterations=2000, l2_leaf_reg=5, learning_rate=0.03, random_strength=0.5;, score=0.833 total time= 1.6min
# [CV 2/6; 7/20] START bagging_temperature=0.0, border_count=32, depth=8, iterations=1000, l2_leaf_reg=7, learning_rate=0.1, random_strength=1.0
# 0:	test: 0.8055556	best: 0.8055556 (0)	total: 2.06s	remaining: 34m 14s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.8222222222
# bestIteration = 19
#
# Shrink model to first 20 iterations.
# [CV 2/6; 5/20] END bagging_temperature=0.5, border_count=64, depth=10, iterations=2000, l2_leaf_reg=5, learning_rate=0.1, random_strength=1.0;, score=0.810 total time= 4.9min
# [CV 3/6; 7/20] START bagging_temperature=0.0, border_count=32, depth=8, iterations=1000, l2_leaf_reg=7, learning_rate=0.1, random_strength=1.0
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.7444444444
# bestIteration = 59
#
# Shrink model to first 60 iterations.
# [CV 4/6; 6/20] END bagging_temperature=0.5, border_count=128, depth=8, iterations=2000, l2_leaf_reg=5, learning_rate=0.03, random_strength=0.5;, score=0.714 total time= 3.1min
# 0:	test: 0.6000000	best: 0.6000000 (0)	total: 255ms	remaining: 4m 14s
# [CV 4/6; 7/20] START bagging_temperature=0.0, border_count=32, depth=8, iterations=1000, l2_leaf_reg=7, learning_rate=0.1, random_strength=1.0
# 0:	test: 0.6444444	best: 0.6444444 (0)	total: 1.02s	remaining: 17m 4s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.8333333333
# bestIteration = 6
#
# Shrink model to first 7 iterations.
# [CV 6/6; 6/20] END bagging_temperature=0.5, border_count=128, depth=8, iterations=2000, l2_leaf_reg=5, learning_rate=0.03, random_strength=0.5;, score=0.806 total time= 1.7min
# [CV 5/6; 7/20] START bagging_temperature=0.0, border_count=32, depth=8, iterations=1000, l2_leaf_reg=7, learning_rate=0.1, random_strength=1.0
# 0:	test: 0.6444444	best: 0.6444444 (0)	total: 2.2s	remaining: 36m 38s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.8833333333
# bestIteration = 4
#
# Shrink model to first 5 iterations.
# [CV 1/6; 7/20] END bagging_temperature=0.0, border_count=32, depth=8, iterations=1000, l2_leaf_reg=7, learning_rate=0.1, random_strength=1.0;, score=0.881 total time= 1.5min
# [CV 6/6; 7/20] START bagging_temperature=0.0, border_count=32, depth=8, iterations=1000, l2_leaf_reg=7, learning_rate=0.1, random_strength=1.0
# 0:	test: 0.6666667	best: 0.6666667 (0)	total: 2.1s	remaining: 34m 54s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 1
# bestIteration = 12
#
# Shrink model to first 13 iterations.
# [CV 6/6; 5/20] END bagging_temperature=0.5, border_count=64, depth=10, iterations=2000, l2_leaf_reg=5, learning_rate=0.1, random_strength=1.0;, score=0.917 total time= 6.0min
# [CV 1/6; 8/20] START bagging_temperature=0.5, border_count=32, depth=4, iterations=1000, l2_leaf_reg=7, learning_rate=0.1, random_strength=1.0
# 0:	test: 0.6444444	best: 0.6444444 (0)	total: 216ms	remaining: 3m 36s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.8333333333
# bestIteration = 8
#
# Shrink model to first 9 iterations.
# [CV 1/6; 8/20] END bagging_temperature=0.5, border_count=32, depth=4, iterations=1000, l2_leaf_reg=7, learning_rate=0.1, random_strength=1.0;, score=0.952 total time=  12.2s
# [CV 2/6; 8/20] START bagging_temperature=0.5, border_count=32, depth=4, iterations=1000, l2_leaf_reg=7, learning_rate=0.1, random_strength=1.0
# 0:	test: 0.6500000	best: 0.6500000 (0)	total: 364ms	remaining: 6m 4s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.8222222222
# bestIteration = 39
#
# Shrink model to first 40 iterations.
# [CV 2/6; 8/20] END bagging_temperature=0.5, border_count=32, depth=4, iterations=1000, l2_leaf_reg=7, learning_rate=0.1, random_strength=1.0;, score=0.905 total time=  18.6s
# [CV 3/6; 8/20] START bagging_temperature=0.5, border_count=32, depth=4, iterations=1000, l2_leaf_reg=7, learning_rate=0.1, random_strength=1.0
# 0:	test: 0.6000000	best: 0.6000000 (0)	total: 126ms	remaining: 2m 6s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.8722222222
# bestIteration = 7
#
# Shrink model to first 8 iterations.
# [CV 3/6; 8/20] END bagging_temperature=0.5, border_count=32, depth=4, iterations=1000, l2_leaf_reg=7, learning_rate=0.1, random_strength=1.0;, score=0.762 total time=  12.3s
# [CV 4/6; 8/20] START bagging_temperature=0.5, border_count=32, depth=4, iterations=1000, l2_leaf_reg=7, learning_rate=0.1, random_strength=1.0
# 0:	test: 0.6555556	best: 0.6555556 (0)	total: 253ms	remaining: 4m 13s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.8222222222
# bestIteration = 7
#
# Shrink model to first 8 iterations.
# [CV 5/6; 7/20] END bagging_temperature=0.0, border_count=32, depth=8, iterations=1000, l2_leaf_reg=7, learning_rate=0.1, random_strength=1.0;, score=0.875 total time= 2.1min
# [CV 5/6; 8/20] START bagging_temperature=0.5, border_count=32, depth=4, iterations=1000, l2_leaf_reg=7, learning_rate=0.1, random_strength=1.0
# 0:	test: 0.6444444	best: 0.6444444 (0)	total: 306ms	remaining: 5m 5s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.7777777778
# bestIteration = 49
#
# Shrink model to first 50 iterations.
# [CV 4/6; 8/20] END bagging_temperature=0.5, border_count=32, depth=4, iterations=1000, l2_leaf_reg=7, learning_rate=0.1, random_strength=1.0;, score=0.690 total time=  19.9s
# [CV 6/6; 8/20] START bagging_temperature=0.5, border_count=32, depth=4, iterations=1000, l2_leaf_reg=7, learning_rate=0.1, random_strength=1.0
# 0:	test: 0.5833333	best: 0.5833333 (0)	total: 184ms	remaining: 3m 3s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.9111111111
# bestIteration = 14
#
# Shrink model to first 15 iterations.
# [CV 6/6; 8/20] END bagging_temperature=0.5, border_count=32, depth=4, iterations=1000, l2_leaf_reg=7, learning_rate=0.1, random_strength=1.0;, score=0.861 total time=  13.1s
# [CV 1/6; 9/20] START bagging_temperature=0.5, border_count=64, depth=8, iterations=2000, l2_leaf_reg=10, learning_rate=0.1, random_strength=1.0
# 0:	test: 0.7777778	best: 0.7777778 (0)	total: 2s	remaining: 1h 6m 29s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.8666666667
# bestIteration = 49
#
# Shrink model to first 50 iterations.
# [CV 5/6; 8/20] END bagging_temperature=0.5, border_count=32, depth=4, iterations=1000, l2_leaf_reg=7, learning_rate=0.1, random_strength=1.0;, score=0.889 total time=  20.0s
# [CV 2/6; 9/20] START bagging_temperature=0.5, border_count=64, depth=8, iterations=2000, l2_leaf_reg=10, learning_rate=0.1, random_strength=1.0
# 0:	test: 0.8055556	best: 0.8055556 (0)	total: 1.8s	remaining: 1h 5s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.8444444444
# bestIteration = 31
#
# Shrink model to first 32 iterations.
# [CV 4/6; 7/20] END bagging_temperature=0.0, border_count=32, depth=8, iterations=1000, l2_leaf_reg=7, learning_rate=0.1, random_strength=1.0;, score=0.714 total time= 2.8min
# [CV 3/6; 9/20] START bagging_temperature=0.5, border_count=64, depth=8, iterations=2000, l2_leaf_reg=10, learning_rate=0.1, random_strength=1.0
# 0:	test: 0.6000000	best: 0.6000000 (0)	total: 257ms	remaining: 8m 33s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.9222222222
# bestIteration = 28
#
# Shrink model to first 29 iterations.
# [CV 6/6; 7/20] END bagging_temperature=0.0, border_count=32, depth=8, iterations=1000, l2_leaf_reg=7, learning_rate=0.1, random_strength=1.0;, score=0.917 total time= 2.7min
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.8555555556
# bestIteration = 34
#
# Shrink model to first 35 iterations.
# [CV 3/6; 5/20] END bagging_temperature=0.5, border_count=64, depth=10, iterations=2000, l2_leaf_reg=5, learning_rate=0.1, random_strength=1.0;, score=0.976 total time= 7.9min
# [CV 5/6; 9/20] START bagging_temperature=0.5, border_count=64, depth=8, iterations=2000, l2_leaf_reg=10, learning_rate=0.1, random_strength=1.0
# 0:	test: 0.6444444	best: 0.6444444 (0)	total: 1.82s	remaining: 1h 36s
# [CV 4/6; 9/20] START bagging_temperature=0.5, border_count=64, depth=8, iterations=2000, l2_leaf_reg=10, learning_rate=0.1, random_strength=1.0
# 0:	test: 0.6444444	best: 0.6444444 (0)	total: 1.1s	remaining: 36m 40s
# 100:	test: 0.7555556	best: 0.8666667 (52)	total: 3m 26s	remaining: 30m 39s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.9222222222
# bestIteration = 46
#
# Shrink model to first 47 iterations.
# [CV 3/6; 7/20] END bagging_temperature=0.0, border_count=32, depth=8, iterations=1000, l2_leaf_reg=7, learning_rate=0.1, random_strength=1.0;, score=0.881 total time= 3.2min
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.8666666667
# bestIteration = 52
#
# Shrink model to first 53 iterations.
# [CV 2/6; 7/20] END bagging_temperature=0.0, border_count=32, depth=8, iterations=1000, l2_leaf_reg=7, learning_rate=0.1, random_strength=1.0;, score=1.000 total time= 3.5min
# [CV 6/6; 9/20] START bagging_temperature=0.5, border_count=64, depth=8, iterations=2000, l2_leaf_reg=10, learning_rate=0.1, random_strength=1.0
# 0:	test: 0.6555556	best: 0.6555556 (0)	total: 482ms	remaining: 16m 4s
# [CV 1/6; 10/20] START bagging_temperature=1.0, border_count=128, depth=8, iterations=500, l2_leaf_reg=7, learning_rate=0.05, random_strength=1.0
# 0:	test: 0.7777778	best: 0.7777778 (0)	total: 284ms	remaining: 2m 21s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.8
# bestIteration = 13
#
# Shrink model to first 14 iterations.
# [CV 1/6; 9/20] END bagging_temperature=0.5, border_count=64, depth=8, iterations=2000, l2_leaf_reg=10, learning_rate=0.1, random_strength=1.0;, score=0.952 total time= 1.7min
# [CV 2/6; 10/20] START bagging_temperature=1.0, border_count=128, depth=8, iterations=500, l2_leaf_reg=7, learning_rate=0.05, random_strength=1.0
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.8555555556
# bestIteration = 39
#
# Shrink model to first 40 iterations.
# [CV 5/6; 5/20] END bagging_temperature=0.5, border_count=64, depth=10, iterations=2000, l2_leaf_reg=5, learning_rate=0.1, random_strength=1.0;, score=0.917 total time= 9.1min
# [CV 3/6; 10/20] START bagging_temperature=1.0, border_count=128, depth=8, iterations=500, l2_leaf_reg=7, learning_rate=0.05, random_strength=1.0
# 0:	test: 0.6000000	best: 0.6000000 (0)	total: 178ms	remaining: 1m 28s
# 0:	test: 0.8055556	best: 0.8055556 (0)	total: 2.03s	remaining: 16m 52s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.8888888889
# bestIteration = 17
#
# Shrink model to first 18 iterations.
# [CV 3/6; 9/20] END bagging_temperature=0.5, border_count=64, depth=8, iterations=2000, l2_leaf_reg=10, learning_rate=0.1, random_strength=1.0;, score=0.881 total time= 1.9min
# [CV 4/6; 10/20] START bagging_temperature=1.0, border_count=128, depth=8, iterations=500, l2_leaf_reg=7, learning_rate=0.05, random_strength=1.0
# 0:	test: 0.6444444	best: 0.6444444 (0)	total: 1.17s	remaining: 9m 44s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.8333333333
# bestIteration = 29
#
# Shrink model to first 30 iterations.
# [CV 2/6; 9/20] END bagging_temperature=0.5, border_count=64, depth=8, iterations=2000, l2_leaf_reg=10, learning_rate=0.1, random_strength=1.0;, score=0.952 total time= 2.1min
# [CV 5/6; 10/20] START bagging_temperature=1.0, border_count=128, depth=8, iterations=500, l2_leaf_reg=7, learning_rate=0.05, random_strength=1.0
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.8666666667
# bestIteration = 4
#
# Shrink model to first 5 iterations.
# [CV 1/6; 10/20] END bagging_temperature=1.0, border_count=128, depth=8, iterations=500, l2_leaf_reg=7, learning_rate=0.05, random_strength=1.0;, score=0.929 total time= 1.4min
# [CV 6/6; 10/20] START bagging_temperature=1.0, border_count=128, depth=8, iterations=500, l2_leaf_reg=7, learning_rate=0.05, random_strength=1.0
# 0:	test: 0.6000000	best: 0.6000000 (0)	total: 702ms	remaining: 5m 50s
# 0:	test: 0.6444444	best: 0.6444444 (0)	total: 2.05s	remaining: 17m 5s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.8888888889
# bestIteration = 23
#
# Shrink model to first 24 iterations.
# [CV 5/6; 9/20] END bagging_temperature=0.5, border_count=64, depth=8, iterations=2000, l2_leaf_reg=10, learning_rate=0.1, random_strength=1.0;, score=0.917 total time= 2.2min
# [CV 1/6; 11/20] START bagging_temperature=0.0, border_count=128, depth=6, iterations=1000, l2_leaf_reg=1, learning_rate=0.05, random_strength=0.5
# 0:	test: 0.7166667	best: 0.7166667 (0)	total: 588ms	remaining: 9m 47s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.8888888889
# bestIteration = 26
#
# Shrink model to first 27 iterations.
# [CV 6/6; 9/20] END bagging_temperature=0.5, border_count=64, depth=8, iterations=2000, l2_leaf_reg=10, learning_rate=0.1, random_strength=1.0;, score=0.889 total time= 2.4min
# [CV 2/6; 11/20] START bagging_temperature=0.0, border_count=128, depth=6, iterations=1000, l2_leaf_reg=1, learning_rate=0.05, random_strength=0.5
# 0:	test: 0.7888889	best: 0.7888889 (0)	total: 822ms	remaining: 13m 40s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.8555555556
# bestIteration = 1
#
# Shrink model to first 2 iterations.
# [CV 1/6; 11/20] END bagging_temperature=0.0, border_count=128, depth=6, iterations=1000, l2_leaf_reg=1, learning_rate=0.05, random_strength=0.5;, score=0.762 total time=  30.5s
# [CV 3/6; 11/20] START bagging_temperature=0.0, border_count=128, depth=6, iterations=1000, l2_leaf_reg=1, learning_rate=0.05, random_strength=0.5
# 0:	test: 0.7444444	best: 0.7444444 (0)	total: 524ms	remaining: 8m 43s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.8888888889
# bestIteration = 16
#
# Shrink model to first 17 iterations.
# [CV 2/6; 10/20] END bagging_temperature=1.0, border_count=128, depth=8, iterations=500, l2_leaf_reg=7, learning_rate=0.05, random_strength=1.0;, score=1.000 total time= 1.6min
# [CV 4/6; 11/20] START bagging_temperature=0.0, border_count=128, depth=6, iterations=1000, l2_leaf_reg=1, learning_rate=0.05, random_strength=0.5
# 0:	test: 0.6333333	best: 0.6333333 (0)	total: 368ms	remaining: 6m 7s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.9
# bestIteration = 20
#
# Shrink model to first 21 iterations.
# [CV 3/6; 10/20] END bagging_temperature=1.0, border_count=128, depth=8, iterations=500, l2_leaf_reg=7, learning_rate=0.05, random_strength=1.0;, score=0.929 total time= 1.6min
# [CV 5/6; 11/20] START bagging_temperature=0.0, border_count=128, depth=6, iterations=1000, l2_leaf_reg=1, learning_rate=0.05, random_strength=0.5
# 0:	test: 0.7000000	best: 0.7000000 (0)	total: 676ms	remaining: 11m 15s
# 100:	test: 0.8111111	best: 0.8111111 (52)	total: 2m 54s	remaining: 54m 43s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.8111111111
# bestIteration = 52
#
# Shrink model to first 53 iterations.
# [CV 4/6; 9/20] END bagging_temperature=0.5, border_count=64, depth=8, iterations=2000, l2_leaf_reg=10, learning_rate=0.1, random_strength=1.0;, score=0.667 total time= 3.0min
# [CV 6/6; 11/20] START bagging_temperature=0.0, border_count=128, depth=6, iterations=1000, l2_leaf_reg=1, learning_rate=0.05, random_strength=0.5
# 0:	test: 0.6277778	best: 0.6277778 (0)	total: 444ms	remaining: 7m 24s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.8833333333
# bestIteration = 6
#
# Shrink model to first 7 iterations.
# [CV 2/6; 11/20] END bagging_temperature=0.0, border_count=128, depth=6, iterations=1000, l2_leaf_reg=1, learning_rate=0.05, random_strength=0.5;, score=0.786 total time=  26.6s
# [CV 1/6; 12/20] START bagging_temperature=0.0, border_count=64, depth=4, iterations=500, l2_leaf_reg=10, learning_rate=0.03, random_strength=0.5
# 0:	test: 0.7055556	best: 0.7055556 (0)	total: 336ms	remaining: 2m 47s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.75
# bestIteration = 3
#
# Shrink model to first 4 iterations.
# [CV 4/6; 11/20] END bagging_temperature=0.0, border_count=128, depth=6, iterations=1000, l2_leaf_reg=1, learning_rate=0.05, random_strength=0.5;, score=0.643 total time=  23.4s
# [CV 2/6; 12/20] START bagging_temperature=0.0, border_count=64, depth=4, iterations=500, l2_leaf_reg=10, learning_rate=0.03, random_strength=0.5
# 0:	test: 0.6666667	best: 0.6666667 (0)	total: 140ms	remaining: 1m 9s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.8444444444
# bestIteration = 2
#
# Shrink model to first 3 iterations.
# [CV 5/6; 11/20] END bagging_temperature=0.0, border_count=128, depth=6, iterations=1000, l2_leaf_reg=1, learning_rate=0.05, random_strength=0.5;, score=0.889 total time=  24.3s
# [CV 3/6; 12/20] START bagging_temperature=0.0, border_count=64, depth=4, iterations=500, l2_leaf_reg=10, learning_rate=0.03, random_strength=0.5
# 0:	test: 0.6722222	best: 0.6722222 (0)	total: 222ms	remaining: 1m 50s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.8888888889
# bestIteration = 21
#
# Shrink model to first 22 iterations.
# [CV 3/6; 11/20] END bagging_temperature=0.0, border_count=128, depth=6, iterations=1000, l2_leaf_reg=1, learning_rate=0.05, random_strength=0.5;, score=0.929 total time=  32.7s
# [CV 4/6; 12/20] START bagging_temperature=0.0, border_count=64, depth=4, iterations=500, l2_leaf_reg=10, learning_rate=0.03, random_strength=0.5
# 0:	test: 0.6444444	best: 0.6444444 (0)	total: 138ms	remaining: 1m 8s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.7722222222
# bestIteration = 1
#
# Shrink model to first 2 iterations.
# [CV 1/6; 12/20] END bagging_temperature=0.0, border_count=64, depth=4, iterations=500, l2_leaf_reg=10, learning_rate=0.03, random_strength=0.5;, score=0.690 total time=  15.6s
# [CV 5/6; 12/20] START bagging_temperature=0.0, border_count=64, depth=4, iterations=500, l2_leaf_reg=10, learning_rate=0.03, random_strength=0.5
# 0:	test: 0.6500000	best: 0.6500000 (0)	total: 144ms	remaining: 1m 11s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.7333333333
# bestIteration = 2
#
# Shrink model to first 3 iterations.
# [CV 2/6; 12/20] END bagging_temperature=0.0, border_count=64, depth=4, iterations=500, l2_leaf_reg=10, learning_rate=0.03, random_strength=0.5;, score=0.738 total time=  14.9s
# [CV 6/6; 12/20] START bagging_temperature=0.0, border_count=64, depth=4, iterations=500, l2_leaf_reg=10, learning_rate=0.03, random_strength=0.5
# 0:	test: 0.7111111	best: 0.7111111 (0)	total: 146ms	remaining: 1m 12s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.7888888889
# bestIteration = 16
#
# Shrink model to first 17 iterations.
# [CV 5/6; 12/20] END bagging_temperature=0.0, border_count=64, depth=4, iterations=500, l2_leaf_reg=10, learning_rate=0.03, random_strength=0.5;, score=1.000 total time=  30.8s
# [CV 1/6; 13/20] START bagging_temperature=1.0, border_count=32, depth=8, iterations=1000, l2_leaf_reg=10, learning_rate=0.03, random_strength=0.5
# 0:	test: 0.4388889	best: 0.4388889 (0)	total: 1.26s	remaining: 20m 58s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.8722222222
# bestIteration = 5
#
# Shrink model to first 6 iterations.
# [CV 6/6; 12/20] END bagging_temperature=0.0, border_count=64, depth=4, iterations=500, l2_leaf_reg=10, learning_rate=0.03, random_strength=0.5;, score=0.944 total time=  28.9s
# [CV 2/6; 13/20] START bagging_temperature=1.0, border_count=32, depth=8, iterations=1000, l2_leaf_reg=10, learning_rate=0.03, random_strength=0.5
# 0:	test: 0.7166667	best: 0.7166667 (0)	total: 1.35s	remaining: 22m 26s
# 100:	test: 0.7555556	best: 0.7555556 (81)	total: 17.5s	remaining: 1m 9s
# 100:	test: 0.8000000	best: 0.8333333 (52)	total: 18.6s	remaining: 1m 13s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.8333333333
# bestIteration = 52
#
# Shrink model to first 53 iterations.
# [CV 3/6; 12/20] END bagging_temperature=0.0, border_count=64, depth=4, iterations=500, l2_leaf_reg=10, learning_rate=0.03, random_strength=0.5;, score=0.952 total time=  43.1s
# [CV 3/6; 13/20] START bagging_temperature=1.0, border_count=32, depth=8, iterations=1000, l2_leaf_reg=10, learning_rate=0.03, random_strength=0.5
# 0:	test: 0.8055556	best: 0.8055556 (0)	total: 1.41s	remaining: 23m 30s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.7555555556
# bestIteration = 81
#
# Shrink model to first 82 iterations.
# [CV 4/6; 12/20] END bagging_temperature=0.0, border_count=64, depth=4, iterations=500, l2_leaf_reg=10, learning_rate=0.03, random_strength=0.5;, score=0.690 total time=  48.7s
# [CV 4/6; 13/20] START bagging_temperature=1.0, border_count=32, depth=8, iterations=1000, l2_leaf_reg=10, learning_rate=0.03, random_strength=0.5
# 0:	test: 0.5944444	best: 0.5944444 (0)	total: 1.69s	remaining: 28m 9s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.8
# bestIteration = 30
#
# Shrink model to first 31 iterations.
# [CV 6/6; 11/20] END bagging_temperature=0.0, border_count=128, depth=6, iterations=1000, l2_leaf_reg=1, learning_rate=0.05, random_strength=0.5;, score=0.944 total time= 1.0min
# [CV 5/6; 13/20] START bagging_temperature=1.0, border_count=32, depth=8, iterations=1000, l2_leaf_reg=10, learning_rate=0.03, random_strength=0.5
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.8555555556
# bestIteration = 32
#
# Shrink model to first 33 iterations.
# [CV 5/6; 10/20] END bagging_temperature=1.0, border_count=128, depth=8, iterations=500, l2_leaf_reg=7, learning_rate=0.05, random_strength=1.0;, score=0.917 total time= 2.4min
# [CV 6/6; 13/20] START bagging_temperature=1.0, border_count=32, depth=8, iterations=1000, l2_leaf_reg=10, learning_rate=0.03, random_strength=0.5
# 0:	test: 0.7166667	best: 0.7166667 (0)	total: 1.91s	remaining: 31m 50s
# 0:	test: 0.6722222	best: 0.6722222 (0)	total: 1.54s	remaining: 25m 40s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.8111111111
# bestIteration = 42
#
# Shrink model to first 43 iterations.
# [CV 6/6; 10/20] END bagging_temperature=1.0, border_count=128, depth=8, iterations=500, l2_leaf_reg=7, learning_rate=0.05, random_strength=1.0;, score=0.889 total time= 2.4min
# [CV 1/6; 14/20] START bagging_temperature=0.25, border_count=32, depth=6, iterations=1000, l2_leaf_reg=5, learning_rate=0.1, random_strength=0.5
# 0:	test: 0.6888889	best: 0.6888889 (0)	total: 686ms	remaining: 11m 24s
# 100:	test: 0.7444444	best: 0.8111111 (62)	total: 2m 12s	remaining: 8m 42s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.8111111111
# bestIteration = 62
#
# Shrink model to first 63 iterations.
# [CV 4/6; 10/20] END bagging_temperature=1.0, border_count=128, depth=8, iterations=500, l2_leaf_reg=7, learning_rate=0.05, random_strength=1.0;, score=0.762 total time= 2.9min
# [CV 2/6; 14/20] START bagging_temperature=0.25, border_count=32, depth=6, iterations=1000, l2_leaf_reg=5, learning_rate=0.1, random_strength=0.5
# 0:	test: 0.6277778	best: 0.6277778 (0)	total: 364ms	remaining: 6m 3s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.7
# bestIteration = 19
#
# Shrink model to first 20 iterations.
# [CV 1/6; 14/20] END bagging_temperature=0.25, border_count=32, depth=6, iterations=1000, l2_leaf_reg=5, learning_rate=0.1, random_strength=0.5;, score=0.929 total time=  52.3s
# [CV 3/6; 14/20] START bagging_temperature=0.25, border_count=32, depth=6, iterations=1000, l2_leaf_reg=5, learning_rate=0.1, random_strength=0.5
# 0:	test: 0.7111111	best: 0.7111111 (0)	total: 728ms	remaining: 12m 7s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.7444444444
# bestIteration = 1
#
# Shrink model to first 2 iterations.
# [CV 2/6; 13/20] END bagging_temperature=1.0, border_count=32, depth=8, iterations=1000, l2_leaf_reg=10, learning_rate=0.03, random_strength=0.5;, score=0.631 total time= 1.5min
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.8777777778
# bestIteration = 4
#
# Shrink model to first 5 iterations.
# [CV 3/6; 13/20] END bagging_temperature=1.0, border_count=32, depth=8, iterations=1000, l2_leaf_reg=10, learning_rate=0.03, random_strength=0.5;, score=1.000 total time= 1.5min
# [CV 4/6; 14/20] START bagging_temperature=0.25, border_count=32, depth=6, iterations=1000, l2_leaf_reg=5, learning_rate=0.1, random_strength=0.5
# 0:	test: 0.6222222	best: 0.6222222 (0)	total: 386ms	remaining: 6m 25s
# [CV 5/6; 14/20] START bagging_temperature=0.25, border_count=32, depth=6, iterations=1000, l2_leaf_reg=5, learning_rate=0.1, random_strength=0.5
# 0:	test: 0.6666667	best: 0.6666667 (0)	total: 1.62s	remaining: 26m 55s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.8666666667
# bestIteration = 3
#
# Shrink model to first 4 iterations.
# [CV 3/6; 14/20] END bagging_temperature=0.25, border_count=32, depth=6, iterations=1000, l2_leaf_reg=5, learning_rate=0.1, random_strength=0.5;, score=0.976 total time=  51.6s
# [CV 6/6; 14/20] START bagging_temperature=0.25, border_count=32, depth=6, iterations=1000, l2_leaf_reg=5, learning_rate=0.1, random_strength=0.5
# 0:	test: 0.8000000	best: 0.8000000 (0)	total: 774ms	remaining: 12m 52s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.8444444444
# bestIteration = 3
#
# Shrink model to first 4 iterations.
# [CV 5/6; 13/20] END bagging_temperature=1.0, border_count=32, depth=8, iterations=1000, l2_leaf_reg=10, learning_rate=0.03, random_strength=0.5;, score=0.847 total time= 1.9min
# [CV 1/6; 15/20] START bagging_temperature=0.5, border_count=64, depth=6, iterations=1000, l2_leaf_reg=5, learning_rate=0.05, random_strength=2.0
# 0:	test: 0.6444444	best: 0.6444444 (0)	total: 389ms	remaining: 6m 28s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.8222222222
# bestIteration = 47
#
# Shrink model to first 48 iterations.
# [CV 2/6; 14/20] END bagging_temperature=0.25, border_count=32, depth=6, iterations=1000, l2_leaf_reg=5, learning_rate=0.1, random_strength=0.5;, score=0.905 total time= 1.6min
# [CV 2/6; 15/20] START bagging_temperature=0.5, border_count=64, depth=6, iterations=1000, l2_leaf_reg=5, learning_rate=0.05, random_strength=2.0
# 0:	test: 0.6166667	best: 0.6166667 (0)	total: 416ms	remaining: 6m 56s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.7555555556
# bestIteration = 19
#
# Shrink model to first 20 iterations.
# [CV 4/6; 14/20] END bagging_temperature=0.25, border_count=32, depth=6, iterations=1000, l2_leaf_reg=5, learning_rate=0.1, random_strength=0.5;, score=0.690 total time= 1.0min
# [CV 3/6; 15/20] START bagging_temperature=0.5, border_count=64, depth=6, iterations=1000, l2_leaf_reg=5, learning_rate=0.05, random_strength=2.0
# 0:	test: 0.6000000	best: 0.6000000 (0)	total: 172ms	remaining: 2m 51s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.8888888889
# bestIteration = 2
#
# Shrink model to first 3 iterations.
# [CV 6/6; 14/20] END bagging_temperature=0.25, border_count=32, depth=6, iterations=1000, l2_leaf_reg=5, learning_rate=0.1, random_strength=0.5;, score=0.944 total time=  38.3s
# [CV 4/6; 15/20] START bagging_temperature=0.5, border_count=64, depth=6, iterations=1000, l2_leaf_reg=5, learning_rate=0.05, random_strength=2.0
# 0:	test: 0.6444444	best: 0.6444444 (0)	total: 340ms	remaining: 5m 39s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.9666666667
# bestIteration = 17
#
# Shrink model to first 18 iterations.
# [CV 1/6; 15/20] END bagging_temperature=0.5, border_count=64, depth=6, iterations=1000, l2_leaf_reg=5, learning_rate=0.05, random_strength=2.0;, score=0.976 total time=  39.7s
# [CV 5/6; 15/20] START bagging_temperature=0.5, border_count=64, depth=6, iterations=1000, l2_leaf_reg=5, learning_rate=0.05, random_strength=2.0
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.8111111111
# bestIteration = 24
#
# Shrink model to first 25 iterations.
# [CV 5/6; 14/20] END bagging_temperature=0.25, border_count=32, depth=6, iterations=1000, l2_leaf_reg=5, learning_rate=0.1, random_strength=0.5;, score=0.917 total time= 1.1min
# 0:	test: 0.6444444	best: 0.6444444 (0)	total: 438ms	remaining: 7m 17s
# [CV 6/6; 15/20] START bagging_temperature=0.5, border_count=64, depth=6, iterations=1000, l2_leaf_reg=5, learning_rate=0.05, random_strength=2.0
# 0:	test: 0.5833333	best: 0.5833333 (0)	total: 426ms	remaining: 7m 5s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.8666666667
# bestIteration = 24
#
# Shrink model to first 25 iterations.
# [CV 6/6; 13/20] END bagging_temperature=1.0, border_count=32, depth=8, iterations=1000, l2_leaf_reg=10, learning_rate=0.03, random_strength=0.5;, score=1.000 total time= 2.8min
# [CV 1/6; 16/20] START bagging_temperature=0.5, border_count=64, depth=4, iterations=500, l2_leaf_reg=1, learning_rate=0.1, random_strength=2.0
# 0:	test: 0.6000000	best: 0.6000000 (0)	total: 202ms	remaining: 1m 40s
# Stopped by overfitting detector  (50 iterations wait)
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6666666667
# bestIteration = 37
#
# Shrink model to first 38 iterations.
#
# bestTest = 0.8666666667
# bestIteration = 22
#
# Shrink model to first 23 iterations.
# [CV 1/6; 13/20] END bagging_temperature=1.0, border_count=32, depth=8, iterations=1000, l2_leaf_reg=10, learning_rate=0.03, random_strength=0.5;, score=0.905 total time= 3.0min
# [CV 2/6; 16/20] START bagging_temperature=0.5, border_count=64, depth=4, iterations=500, l2_leaf_reg=1, learning_rate=0.1, random_strength=2.0
# [CV 2/6; 15/20] END bagging_temperature=0.5, border_count=64, depth=6, iterations=1000, l2_leaf_reg=5, learning_rate=0.05, random_strength=2.0;, score=0.833 total time=  49.0s
# [CV 3/6; 16/20] START bagging_temperature=0.5, border_count=64, depth=4, iterations=500, l2_leaf_reg=1, learning_rate=0.1, random_strength=2.0
# 0:	test: 0.6000000	best: 0.6000000 (0)	total: 171ms	remaining: 1m 25s
# 0:	test: 0.6000000	best: 0.6000000 (0)	total: 78.9ms	remaining: 39.4s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.9055555556
# bestIteration = 6
#
# Shrink model to first 7 iterations.
# [CV 2/6; 16/20] END bagging_temperature=0.5, border_count=64, depth=4, iterations=500, l2_leaf_reg=1, learning_rate=0.1, random_strength=2.0;, score=0.893 total time=  12.2s
# [CV 4/6; 16/20] START bagging_temperature=0.5, border_count=64, depth=4, iterations=500, l2_leaf_reg=1, learning_rate=0.1, random_strength=2.0
# 0:	test: 0.6222222	best: 0.6222222 (0)	total: 346ms	remaining: 2m 52s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.7888888889
# bestIteration = 28
#
# Shrink model to first 29 iterations.
# [CV 1/6; 16/20] END bagging_temperature=0.5, border_count=64, depth=4, iterations=500, l2_leaf_reg=1, learning_rate=0.1, random_strength=2.0;, score=0.905 total time=  20.2s
# ...
# 0:	test: 0.5333333	best: 0.5333333 (0)	total: 9.9s	remaining: 5h 29m 59s
# 100:	test: 0.8333333	best: 0.8444444 (82)	total: 24.6s	remaining: 1m 37s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.9777777778
# bestIteration = 49
#
# Shrink model to first 50 iterations.
# [CV 3/6; 15/20] END bagging_temperature=0.5, border_count=64, depth=6, iterations=1000, l2_leaf_reg=5, learning_rate=0.05, random_strength=2.0;, score=0.952 total time= 1.5min
# 100:	test: 0.8555556	best: 0.8888889 (86)	total: 54s	remaining: 8m
# 100:	test: 0.7888889	best: 0.9000000 (59)	total: 20.2s	remaining: 1m 19s
# [CV 2/6; 17/20] START bagging_temperature=0.5, border_count=128, depth=10, iterations=2000, l2_leaf_reg=1, learning_rate=0.03, random_strength=0.0
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.9
# bestIteration = 59
#
# Shrink model to first 60 iterations.
# [CV 6/6; 16/20] END bagging_temperature=0.5, border_count=64, depth=4, iterations=500, l2_leaf_reg=1, learning_rate=0.1, random_strength=2.0;, score=0.917 total time=  36.8s
# [CV 3/6; 17/20] START bagging_temperature=0.5, border_count=128, depth=10, iterations=2000, l2_leaf_reg=1, learning_rate=0.03, random_strength=0.0
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.8444444444
# bestIteration = 82
#
# Shrink model to first 83 iterations.
# [CV 5/6; 16/20] END bagging_temperature=0.5, border_count=64, depth=4, iterations=500, l2_leaf_reg=1, learning_rate=0.1, random_strength=2.0;, score=0.917 total time=  48.1s
# [CV 4/6; 17/20] START bagging_temperature=0.5, border_count=128, depth=10, iterations=2000, l2_leaf_reg=1, learning_rate=0.03, random_strength=0.0
# 100:	test: 0.8222222	best: 0.8333333 (91)	total: 1m	remaining: 8m 57s
# 100:	test: 0.8000000	best: 0.8444444 (76)	total: 1m 3s	remaining: 9m 25s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.7444444444
# bestIteration = 60
#
# Shrink model to first 61 iterations.
# [CV 4/6; 13/20] END bagging_temperature=1.0, border_count=32, depth=8, iterations=1000, l2_leaf_reg=10, learning_rate=0.03, random_strength=0.5;, score=0.667 total time= 4.1min
# 0:	test: 0.7722222	best: 0.7722222 (0)	total: 12.7s	remaining: 7h 1m 29s
# 0:	test: 0.6166667	best: 0.6166667 (0)	total: 12.8s	remaining: 7h 7m 43s
# 0:	test: 0.5333333	best: 0.5333333 (0)	total: 11.5s	remaining: 6h 23m 10s
# [CV 5/6; 17/20] START bagging_temperature=0.5, border_count=128, depth=10, iterations=2000, l2_leaf_reg=1, learning_rate=0.03, random_strength=0.0
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.8888888889
# bestIteration = 86
#
# Shrink model to first 87 iterations.
# [CV 4/6; 15/20] END bagging_temperature=0.5, border_count=64, depth=6, iterations=1000, l2_leaf_reg=5, learning_rate=0.05, random_strength=2.0;, score=0.762 total time= 1.7min
# [CV 6/6; 17/20] START bagging_temperature=0.5, border_count=128, depth=10, iterations=2000, l2_leaf_reg=1, learning_rate=0.03, random_strength=0.0
# 0:	test: 0.6555556	best: 0.6555556 (0)	total: 5.63s	remaining: 3h 7m 32s
# 0:	test: 0.7000000	best: 0.7000000 (0)	total: 5.45s	remaining: 3h 1m 32s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.8333333333
# bestIteration = 91
#
# Shrink model to first 92 iterations.
# [CV 5/6; 15/20] END bagging_temperature=0.5, border_count=64, depth=6, iterations=1000, l2_leaf_reg=5, learning_rate=0.05, random_strength=2.0;, score=0.944 total time= 1.8min
# [CV 1/6; 18/20] START bagging_temperature=0.0, border_count=64, depth=8, iterations=1000, l2_leaf_reg=7, learning_rate=0.1, random_strength=0.0
# 0:	test: 0.6500000	best: 0.6500000 (0)	total: 1.71s	remaining: 28m 28s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.8555555556
# bestIteration = 118
#
# Shrink model to first 119 iterations.
# [CV 6/6; 15/20] END bagging_temperature=0.5, border_count=64, depth=6, iterations=1000, l2_leaf_reg=5, learning_rate=0.05, random_strength=2.0;, score=0.889 total time= 2.1min
# [CV 2/6; 18/20] START bagging_temperature=0.0, border_count=64, depth=8, iterations=1000, l2_leaf_reg=7, learning_rate=0.1, random_strength=0.0
# 0:	test: 0.7388889	best: 0.7388889 (0)	total: 1.75s	remaining: 29m 14s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6944444444
# bestIteration = 2
#
# Shrink model to first 3 iterations.
# [CV 1/6; 18/20] END bagging_temperature=0.0, border_count=64, depth=8, iterations=1000, l2_leaf_reg=7, learning_rate=0.1, random_strength=0.0;, score=0.833 total time= 1.8min
# [CV 3/6; 18/20] START bagging_temperature=0.0, border_count=64, depth=8, iterations=1000, l2_leaf_reg=7, learning_rate=0.1, random_strength=0.0
# 0:	test: 0.6722222	best: 0.6722222 (0)	total: 1.57s	remaining: 26m 4s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.7444444444
# bestIteration = 11
#
# Shrink model to first 12 iterations.
# [CV 2/6; 18/20] END bagging_temperature=0.0, border_count=64, depth=8, iterations=1000, l2_leaf_reg=7, learning_rate=0.1, random_strength=0.0;, score=0.857 total time= 2.6min
# [CV 4/6; 18/20] START bagging_temperature=0.0, border_count=64, depth=8, iterations=1000, l2_leaf_reg=7, learning_rate=0.1, random_strength=0.0
# 0:	test: 0.5444444	best: 0.5444444 (0)	total: 5.89s	remaining: 1h 38m 8s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.7833333333
# bestIteration = 3
#
# Shrink model to first 4 iterations.
# [CV 3/6; 18/20] END bagging_temperature=0.0, border_count=64, depth=8, iterations=1000, l2_leaf_reg=7, learning_rate=0.1, random_strength=0.0;, score=0.845 total time= 3.0min
# [CV 5/6; 18/20] START bagging_temperature=0.0, border_count=64, depth=8, iterations=1000, l2_leaf_reg=7, learning_rate=0.1, random_strength=0.0
# 0:	test: 0.6444444	best: 0.6444444 (0)	total: 1.71s	remaining: 28m 24s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.5333333333
# bestIteration = 0
#
# Shrink model to first 1 iterations.
# [CV 1/6; 17/20] END bagging_temperature=0.5, border_count=128, depth=10, iterations=2000, l2_leaf_reg=1, learning_rate=0.03, random_strength=0.0;, score=0.679 total time= 7.1min
# [CV 6/6; 18/20] START bagging_temperature=0.0, border_count=64, depth=8, iterations=1000, l2_leaf_reg=7, learning_rate=0.1, random_strength=0.0
# 0:	test: 0.8388889	best: 0.8388889 (0)	total: 1.84s	remaining: 30m 36s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.7833333333
# bestIteration = 2
#
# Shrink model to first 3 iterations.
# [CV 2/6; 17/20] END bagging_temperature=0.5, border_count=128, depth=10, iterations=2000, l2_leaf_reg=1, learning_rate=0.03, random_strength=0.0;, score=0.798 total time= 7.1min
# [CV 1/6; 19/20] START bagging_temperature=0.5, border_count=32, depth=6, iterations=500, l2_leaf_reg=10, learning_rate=0.05, random_strength=2.0
# 0:	test: 0.6444444	best: 0.6444444 (0)	total: 517ms	remaining: 4m 17s
# 100:	test: 0.7000000	best: 0.7000000 (70)	total: 3m 19s	remaining: 29m 33s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6055555556
# bestIteration = 5
#
# Shrink model to first 6 iterations.
# [CV 4/6; 17/20] END bagging_temperature=0.5, border_count=128, depth=10, iterations=2000, l2_leaf_reg=1, learning_rate=0.03, random_strength=0.0;, score=0.536 total time= 7.3min
# [CV 2/6; 19/20] START bagging_temperature=0.5, border_count=32, depth=6, iterations=500, l2_leaf_reg=10, learning_rate=0.05, random_strength=2.0
# 0:	test: 0.7500000	best: 0.7500000 (0)	total: 443ms	remaining: 3m 40s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.8277777778
# bestIteration = 7
#
# Shrink model to first 8 iterations.
# [CV 1/6; 19/20] END bagging_temperature=0.5, border_count=32, depth=6, iterations=500, l2_leaf_reg=10, learning_rate=0.05, random_strength=2.0;, score=0.821 total time=  22.9s
# [CV 3/6; 19/20] START bagging_temperature=0.5, border_count=32, depth=6, iterations=500, l2_leaf_reg=10, learning_rate=0.05, random_strength=2.0
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.8055555556
# bestIteration = 5
#
# Shrink model to first 6 iterations.
# [CV 5/6; 17/20] END bagging_temperature=0.5, border_count=128, depth=10, iterations=2000, l2_leaf_reg=1, learning_rate=0.03, random_strength=0.0;, score=0.931 total time= 7.2min
# 0:	test: 0.6000000	best: 0.6000000 (0)	total: 140ms	remaining: 1m 9s
# [CV 4/6; 19/20] START bagging_temperature=0.5, border_count=32, depth=6, iterations=500, l2_leaf_reg=10, learning_rate=0.05, random_strength=2.0
# 0:	test: 0.6444444	best: 0.6444444 (0)	total: 564ms	remaining: 4m 41s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.7
# bestIteration = 70
#
# Shrink model to first 71 iterations.
# [CV 4/6; 18/20] END bagging_temperature=0.0, border_count=64, depth=8, iterations=1000, l2_leaf_reg=7, learning_rate=0.1, random_strength=0.0;, score=0.690 total time= 4.2min
# [CV 5/6; 19/20] START bagging_temperature=0.5, border_count=32, depth=6, iterations=500, l2_leaf_reg=10, learning_rate=0.05, random_strength=2.0
# 0:	test: 0.6444444	best: 0.6444444 (0)	total: 460ms	remaining: 3m 49s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.8333333333
# bestIteration = 16
#
# Shrink model to first 17 iterations.
# [CV 2/6; 19/20] END bagging_temperature=0.5, border_count=32, depth=6, iterations=500, l2_leaf_reg=10, learning_rate=0.05, random_strength=2.0;, score=0.810 total time=  25.1s
# [CV 6/6; 19/20] START bagging_temperature=0.5, border_count=32, depth=6, iterations=500, l2_leaf_reg=10, learning_rate=0.05, random_strength=2.0
# 0:	test: 0.6888889	best: 0.6888889 (0)	total: 422ms	remaining: 3m 30s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.7555555556
# bestIteration = 32
#
# Shrink model to first 33 iterations.
# [CV 5/6; 18/20] END bagging_temperature=0.0, border_count=64, depth=8, iterations=1000, l2_leaf_reg=7, learning_rate=0.1, random_strength=0.0;, score=0.944 total time= 2.4min
# [CV 1/6; 20/20] START bagging_temperature=0.25, border_count=64, depth=8, iterations=2000, l2_leaf_reg=5, learning_rate=0.03, random_strength=0.5
# 0:	test: 0.7388889	best: 0.7388889 (0)	total: 1.42s	remaining: 47m 11s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.8222222222
# bestIteration = 8
#
# Shrink model to first 9 iterations.
# [CV 6/6; 17/20] END bagging_temperature=0.5, border_count=128, depth=10, iterations=2000, l2_leaf_reg=1, learning_rate=0.03, random_strength=0.0;, score=0.694 total time= 7.8min
# [CV 2/6; 20/20] START bagging_temperature=0.25, border_count=64, depth=8, iterations=2000, l2_leaf_reg=5, learning_rate=0.03, random_strength=0.5
# 100:	test: 0.8444444	best: 0.8555556 (97)	total: 38.1s	remaining: 2m 30s
# 0:	test: 0.8000000	best: 0.8000000 (0)	total: 1.38s	remaining: 45m 58s
# 100:	test: 0.9333333	best: 0.9777778 (81)	total: 39.7s	remaining: 2m 36s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.8555555556
# bestIteration = 10
#
# Shrink model to first 11 iterations.
# [CV 6/6; 18/20] END bagging_temperature=0.0, border_count=64, depth=8, iterations=1000, l2_leaf_reg=7, learning_rate=0.1, random_strength=0.0;, score=0.806 total time= 1.7min
# [CV 3/6; 20/20] START bagging_temperature=0.25, border_count=64, depth=8, iterations=2000, l2_leaf_reg=5, learning_rate=0.03, random_strength=0.5
# 100:	test: 0.8777778	best: 0.9111111 (51)	total: 41.6s	remaining: 2m 44s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.9777777778
# bestIteration = 81
#
# Shrink model to first 82 iterations.
# Stopped by overfitting detector  (50 iterations wait)
# [CV 3/6; 19/20] END bagging_temperature=0.5, border_count=32, depth=6, iterations=500, l2_leaf_reg=10, learning_rate=0.05, random_strength=2.0;, score=0.929 total time=  53.4s
#
# bestTest = 0.9111111111
# bestIteration = 51
#
# Shrink model to first 52 iterations.
# [CV 5/6; 19/20] END bagging_temperature=0.5, border_count=32, depth=6, iterations=500, l2_leaf_reg=10, learning_rate=0.05, random_strength=2.0;, score=0.944 total time=  42.5s
# [CV 4/6; 20/20] START bagging_temperature=0.25, border_count=64, depth=8, iterations=2000, l2_leaf_reg=5, learning_rate=0.03, random_strength=0.5
# [CV 5/6; 20/20] START bagging_temperature=0.25, border_count=64, depth=8, iterations=2000, l2_leaf_reg=5, learning_rate=0.03, random_strength=0.5
# 0:	test: 0.8055556	best: 0.8055556 (0)	total: 1.54s	remaining: 51m 16s
# 0:	test: 0.5833333	best: 0.5833333 (0)	total: 1.49s	remaining: 49m 41s
# 0:	test: 0.7000000	best: 0.7000000 (0)	total: 1.55s	remaining: 51m 48s
# 100:	test: 0.7888889	best: 0.8111111 (59)	total: 40.3s	remaining: 2m 39s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.8555555556
# bestIteration = 97
#
# Shrink model to first 98 iterations.
# [CV 4/6; 19/20] END bagging_temperature=0.5, border_count=32, depth=6, iterations=500, l2_leaf_reg=10, learning_rate=0.05, random_strength=2.0;, score=0.762 total time=  59.2s
# [CV 6/6; 20/20] START bagging_temperature=0.25, border_count=64, depth=8, iterations=2000, l2_leaf_reg=5, learning_rate=0.03, random_strength=0.5
# 0:	test: 0.6277778	best: 0.6277778 (0)	total: 611ms	remaining: 20m 22s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.8111111111
# bestIteration = 59
#
# Shrink model to first 60 iterations.
# [CV 6/6; 19/20] END bagging_temperature=0.5, border_count=32, depth=6, iterations=500, l2_leaf_reg=10, learning_rate=0.05, random_strength=2.0;, score=0.917 total time=  44.4s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.7388888889
# bestIteration = 0
#
# Shrink model to first 1 iterations.
# [CV 1/6; 20/20] END bagging_temperature=0.25, border_count=64, depth=8, iterations=2000, l2_leaf_reg=5, learning_rate=0.03, random_strength=0.5;, score=0.714 total time= 1.1min
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.8333333333
# bestIteration = 9
#
# Shrink model to first 10 iterations.
# [CV 2/6; 20/20] END bagging_temperature=0.25, border_count=64, depth=8, iterations=2000, l2_leaf_reg=5, learning_rate=0.03, random_strength=0.5;, score=0.952 total time= 1.1min
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.9222222222
# bestIteration = 1
#
# Shrink model to first 2 iterations.
# [CV 5/6; 20/20] END bagging_temperature=0.25, border_count=64, depth=8, iterations=2000, l2_leaf_reg=5, learning_rate=0.03, random_strength=0.5;, score=0.833 total time= 1.0min
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.8444444444
# bestIteration = 10
#
# Shrink model to first 11 iterations.
# [CV 3/6; 20/20] END bagging_temperature=0.25, border_count=64, depth=8, iterations=2000, l2_leaf_reg=5, learning_rate=0.03, random_strength=0.5;, score=0.952 total time= 1.0min
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.8333333333
# bestIteration = 6
#
# Shrink model to first 7 iterations.
# [CV 6/6; 20/20] END bagging_temperature=0.25, border_count=64, depth=8, iterations=2000, l2_leaf_reg=5, learning_rate=0.03, random_strength=0.5;, score=0.806 total time=  58.1s
# 100:	test: 0.7222222	best: 0.7444444 (59)	total: 1m 18s	remaining: 24m 28s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.7888888889
# bestIteration = 41
#
# Shrink model to first 42 iterations.
# [CV 3/6; 17/20] END bagging_temperature=0.5, border_count=128, depth=10, iterations=2000, l2_leaf_reg=1, learning_rate=0.03, random_strength=0.0;, score=0.857 total time= 9.6min
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.7444444444
# bestIteration = 59
#
# Shrink model to first 60 iterations.
# [CV 4/6; 20/20] END bagging_temperature=0.25, border_count=64, depth=8, iterations=2000, l2_leaf_reg=5, learning_rate=0.03, random_strength=0.5;, score=0.714 total time= 1.3min
# 0:	test: 0.8388889	best: 0.8388889 (0)	total: 159ms	remaining: 5m 17s
# 100:	test: 0.8333333	best: 0.8555556 (50)	total: 6.55s	remaining: 2m 3s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.8555555556
# bestIteration = 50
#
# Shrink model to first 51 iterations.
# === Лучшие параметры ===
# {'random_strength': 1.0, 'learning_rate': 0.03, 'l2_leaf_reg': 10, 'iterations': 2000, 'depth': 6, 'border_count': 64, 'bagging_temperature': 0.5}
# === Лучший CV AUC ===
# 0.9166666666666666

# %%
# ----------------------------
# Метрики на hold-out X_val
# ----------------------------
val_proba = best_model.predict_proba(X_val)[:, 1]
val_pred  = (val_proba >= 0.5).astype(int)

print("\n=== Метрики на валидации ===")
print("AUC:     ", roc_auc_score(y_val, val_proba))
print("Accuracy:", accuracy_score(y_val, val_pred))
print(classification_report(y_val, val_pred, digits=4))
print("Confusion matrix:\n", confusion_matrix(y_val, val_pred))
# Out:
# === Метрики на валидации ===
# AUC:      0.8555555555555556
# Accuracy: 0.7368421052631579
#               precision    recall  f1-score   support
#
#            0     0.8571    0.6000    0.7059        10
#            1     0.6667    0.8889    0.7619         9
#
#     accuracy                         0.7368        19
#    macro avg     0.7619    0.7444    0.7339        19
# weighted avg     0.7669    0.7368    0.7324        19
#
# Confusion matrix:
#  [[6 4]
#  [1 8]]

# %%
# ----------------------------
# Обучение на всём train (X, y) с лучшими параметрами
# ----------------------------
final_model = CatBoostClassifier(
    **search.best_params_,
    loss_function="Logloss",
    eval_metric="AUC",
    random_seed=RANDOM_STATE,
    verbose=100
)
final_model.fit(X[feature_cols], y, text_features=text_cols)
# Out:
# 0:	total: 71.5ms	remaining: 2m 22s
# 100:	total: 6.73s	remaining: 2m 6s
# 200:	total: 13.8s	remaining: 2m 3s
# 300:	total: 20.7s	remaining: 1m 57s
# 400:	total: 27.6s	remaining: 1m 50s
# 500:	total: 34.6s	remaining: 1m 43s
# 600:	total: 41.4s	remaining: 1m 36s
# 700:	total: 48.5s	remaining: 1m 29s
# 800:	total: 55.6s	remaining: 1m 23s
# 900:	total: 1m 6s	remaining: 1m 21s
# 1000:	total: 1m 14s	remaining: 1m 14s
# 1100:	total: 1m 21s	remaining: 1m 6s
# 1200:	total: 1m 28s	remaining: 59s
# 1300:	total: 1m 36s	remaining: 51.6s
# 1400:	total: 1m 42s	remaining: 44s
# 1500:	total: 1m 50s	remaining: 36.6s
# 1600:	total: 1m 57s	remaining: 29.3s
# 1700:	total: 2m 5s	remaining: 22.1s
# 1800:	total: 2m 12s	remaining: 14.7s
# 1900:	total: 2m 20s	remaining: 7.3s
# 1999:	total: 2m 27s	remaining: 0us

# %%
# ----------------------------
# Инференс на test и сохранение submission
# ----------------------------
test_df_pairs = build_split_df(TEST_DIR)
X_test = test_df_pairs[feature_cols].copy()

test_proba = final_model.predict_proba(X_test)[:, 1]
# правило: >=0.5 -> file_1.txt реал => real_text_id=1, иначе 2
test_pred_real_id = np.where(test_proba >= 0.5, 1, 2).astype(int)

submission = pd.DataFrame({
    "id": test_df_pairs["id"],
    "real_text_id": test_pred_real_id
}).sort_values("id")

out_path = "submission2.csv"
submission.to_csv(out_path, index=False)
print(f"\nSaved: {out_path}")
# Out:
# Saved: submission2.csv
